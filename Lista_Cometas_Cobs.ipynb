# %%
# Librerías
import requests
import pandas as pd

# %%
# Verificar la conexión a internet.
def verificar_conexion():
    try:
        requests.get("http://www.google.com", timeout=5)
        print('✅ Conectado a internet.')
        return True
    
    except requests.ConnectionError:
        print('🛑 Sin conexión a internet.')
        return False

# %%
# Conexión con la API de COBS

Link_cops_API = 'https://cobs.si/api/comet_list.api'

if verificar_conexion():
    response = requests.get(Link_cops_API)


if response.status_code == 200:
    content = response.json()
    print('✅ Base de datos actualizada.')

else:
    print(f'🛑 Se presentó un error al cargar la base de datos.\nError: {response.status_code}\n{response.content}')
# Out:
# ✅ Conectado a internet.
# ✅ Base de datos actualizada.

# %%
cometas_df = pd.DataFrame(content['objects'])
cometas_df
# Out:
#         id type          name                                fullname  \
# 0        1    N     P/2010 H2                       P/2010 H2 (Vales)
# 1        2    C  C/2014 UN271  C/2014 UN271 (Bernardinelli-Bernstein)
# 2        3    C    C/2020 PV6                  C/2020 PV6 (PANSTARRS)
# 3        4    A     A/2021 E4                               A/2021 E4
# 4        6    C     C/2021 G3                   C/2021 G3 (PANSTARRS)
# ...    ...  ...           ...                                     ...
# 2199  2533    N     P/2024 J1                   P/2024 J1 (PANSTARRS)
# 2200  2534    C     C/2024 J4                      C/2024 J4 (Lemmon)
# 2201  2535    C     C/2024 J3                       C/2024 J3 (ATLAS)
# 2202  2536    C   C/2023 TD22                    C/2023 TD22 (Lemmon)
# 2203  2537    C     C/2024 M1                       C/2024 M1 (ATLAS)
#
#      mpc_name  icq_name component current_mag   perihelion_date  \
# 0     K10H020   P2010H2      None        14.1  2025-03-09 15:47
# 1     K14UR1N  2014UNR1      None        18.1  2031-01-17 04:53
# 2     K20P06V   2020PV6      None        24.8  2021-09-26 01:52
# 3     K21E040   A2021E4      None        22.4  2022-04-24 22:00
# 4     K21G030    2021G3      None        24.9  2021-10-17 20:23
# ...       ...       ...       ...         ...               ...
# 2199  K24J010   P2024J1      None        22.4  2023-11-11 04:30
# 2200  K24J040    2024J4      None        19.6  2025-04-26 03:57
# 2201  K24J030    2024J3      None        18.1  2026-11-25 07:55
# 2202  K23T22D  2023TD22      None        17.1  2024-09-16 06:59
# 2203  K24M010    2024M1      None        16.0  2024-11-20 00:51
#
#      perihelion_mag peak_mag peak_mag_date  is_observed  is_active
# 0              12.6     12.5    2025-04-09         True       True
# 1              16.0     15.8    2031-04-04         True       True
# 2              15.6     14.9    2021-08-05         True       True
# 3              20.1     19.8    2022-02-21        False       True
# 4              21.4     20.9    2022-01-31        False       True
# ...             ...      ...           ...          ...        ...
# 2199           21.2     20.2    2024-03-26        False       True
# 2200           19.1     19.1    2025-05-12        False       True
# 2201           13.9     13.7    2026-08-15         True       True
# 2202           17.0     16.9    2024-09-02         True       True
# 2203           13.9     13.7    2024-12-05         True       True
#
# [2204 rows x 14 columns]

# %%
lista_cometas_df = cometas_df[['name', 'fullname']].sort_values(by='name')
lista_cometas_df.name[lista_cometas_df.fullname.str.contains('Halley')].values[0]
# Out:
# '1P'
