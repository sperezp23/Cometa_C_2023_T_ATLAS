# %%
import requests
import pandas as pd
import plotly.express as px

# %%
url = 'https://cobs.si/api/obs_list.api?des=C/2023 A3&format=json&from_date=&to_date=&exclude_faint=False&exclude_not_accurate=False'
response = requests.get(url) 

if response.status_code == 200:
    content = response.json()

# %%
cometa_df = pd.DataFrame(content['objects'])
cometa_df.sort_values('obs_date', ascending=False).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1090 entries, 0 to 1089
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   type                       1090 non-null   object
#  1   obs_date                   1090 non-null   object
#  2   comet                      1090 non-null   object
#  3   observer                   1090 non-null   object
#  4   location                   500 non-null    object
#  5   extinction                 47 non-null     object
#  6   obs_method                 1090 non-null   object
#  7   comet_visibility           1 non-null      object
#  8   magnitude                  1090 non-null   object
#  9   conditions                 14 non-null     object
#  10  ref_catalog                1090 non-null   object
#  11  instrument_aperture        1090 non-null   object
#  12  instrument_type            1090 non-null   object
# ...

# %%
cometa_df['obs_method'] = cometa_df.obs_method.apply(lambda registro: registro['key'])
cometa_df['obs_date'] = pd.to_datetime(cometa_df.obs_date)
cometa_df['magnitude'] = pd.to_numeric(cometa_df.magnitude)

# %%
cometa_df = cometa_df[['obs_method', 'obs_date', 'magnitude']]
cometa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   obs_method  1090 non-null   object
#  1   obs_date    1090 non-null   datetime64[ns]
#  2   magnitude   1090 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 25.7+ KB

# %%
# Gráfica del los datos
labels = {'obs_date':'Observation Date','magnitude':'Apparent total magnitude', 'obs_method':'Meth'}
fig = px.scatter(cometa_df, x='obs_date', y='magnitude', color='obs_method', template= 'plotly_dark', labels= labels, title='Lightcurve of comet C/2023 A3 (Tsuchinshan-ATLAS)')
fig.update_yaxes(autorange="reversed")
fig.show()
